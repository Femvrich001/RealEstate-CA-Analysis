# %%
import pandas as pd

# Replace 'your_file.xlsx' with the actual name of your Excel file
file_path = r"C:\Users\Olajide FemVrich\Documents\FemVrich\DATA\STATS\Section 2\13_Practical Example - Descriptive Statistics\Exercises\2.13.Practical-example.Descriptive-statistics-exercise-solution.xlsx"

# Specify the sheet name or index (0 for the first sheet)
sheet_name = 0

# Read only the first sheet into a DataFrame
df = pd.read_excel(file_path, sheet_name=sheet_name, skiprows=4, usecols=range(1,27))

# Display the DataFrame
df
# Out:
#        ID  Building  Year of sale  Month of sale Type of property  Property #  \
# 0    1030         1        2005.0           11.0        Apartment          30
# 1    1029         1        2005.0           10.0        Apartment          29
# 2    2002         2        2007.0            7.0        Apartment           2
# 3    2031         2        2007.0           12.0        Apartment          31
# 4    1049         1        2004.0           11.0        Apartment          49
# ..    ...       ...           ...            ...              ...         ...
# 262  5044         5           NaN            NaN        Apartment          44
# 263  5047         5           NaN            NaN        Apartment          47
# 264  5048         5           NaN            NaN        Apartment          48
# 265  5050         5           NaN            NaN        Apartment          50
# 266  5051         5           NaN            NaN        Apartment          51
#
# ...

# %%
df.shape
# Out:
# (267, 26)

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = r"C:\Users\Olajide FemVrich\Documents\FemVrich\DATA\STATS\Section 2\13_Practical Example - Descriptive Statistics\Exercises\2.13.Practical-example.Descriptive-statistics-exercise-solution.xlsx"
sheet_name = 0

df = pd.read_excel(file_path, sheet_name=sheet_name, skiprows=4, usecols=range(1,27))

selected_column = df['Price']

# Create a histogram with 267 bins
plt.hist(selected_column, bins=267, edgecolor='black')

# Add labels and title
plt.xlabel('Property Values')
plt.ylabel('Frequency')
plt.title('Frequency Distribution Histogram')

# Show the plot
plt.show()

# %%
# Select the 'Price' column
price_column = df['Price']

# Create a histogram with bins of $100,000 width
bin_width = 20000
bins = range(int(min(price_column)), int(max(price_column)) + bin_width, bin_width)

plt.hist(price_column, bins=bins, edgecolor='black')

# Add labels and title
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Price with $100,000 Bins')

# Show the plot
plt.show()

# %%
Price_column = df["Price"] 
Area_column  = df["Area (ft.)"]

plt.scatter(Area_column,Price_column , alpha=0.7, s=10)
plt.xlabel("Price_column")
plt.ylabel("Area_column")
plt.title("Scatter_plot: Price vs Area")

# Add a text annotation
plt.text(400, 650000, 'As shown on the chart we can see a Linear Relationship btw (price and area)', color='blue', fontsize=12)

# Show the plot
plt.show()

# %%
Countries= df["Country"]

# create a frequency_table 
frequency_table = pd.DataFrame({
    "Country": Countries.value_counts().index,
    "Absolute_frequency": Countries.value_counts().values,
    "Relative_frequency": (Countries.value_counts(normalize=True).values*100).round(0),
    "Cummulative_frequency": (Countries.value_counts(normalize=True).values*100).round(0)
})
# sort the table in descending order in order of the Absolute _frequency
frequency_table = frequency_table.sort_values(by='Absolute_frequency',ascending=False).reset_index(drop=True)

# create another table to display the total 
total_row = pd.DataFrame({
    'Country': ['Total'],
    'Absolute_frequency': [frequency_table['Absolute_frequency'].sum()],
    'Relative_frequency': [100],
    'Cummulative_frequency': [100]
})

# concatinating the frequency_table and the total_table
frequency_table = pd.concat([frequency_table,total_row], ignore_index=True)

print(frequency_table)
# Out:
#    Country  Absolute_frequency  Relative_frequency  Cummulative_frequency
# 0      USA                 177                91.0                   91.0
# 1   Canada                   7                 4.0                    4.0
# 2   Russia                   4                 2.0                    2.0
# 3       UK                   2                 1.0                    1.0
# 4  Belgium                   2                 1.0                    1.0
# 5  Denmark                   1                 1.0                    1.0
# 6  Germany                   1                 1.0                    1.0
# 7   Mexico                   1                 1.0                    1.0
# 8    Total                 195               100.0                  100.0

# %%
# Your frequency table
data = {
    'Country': ['USA', 'Canada', 'Russia', 'UK', 'Belgium', 'Denmark', 'Germany', 'Mexico', 'Total'],
    'Absolute_frequency': [2, 2, 1, 1, 1, 1, 1, 1, 10],
    'Relative_frequency': [20, 20, 10, 10, 10, 10, 10, 10, 100],
    'Cummulative_frequency': [20, 40, 50, 60, 70, 80, 90, 100, 100],
}

frequency_table = pd.DataFrame(data)

# Sort the DataFrame by 'Absolute_frequency' in descending order
frequency_table = frequency_table.sort_values(by='Absolute_frequency', ascending=False)

# Create a Pareto diagram
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart
ax1.bar(frequency_table['Country'], frequency_table['Absolute_frequency'], color='b', alpha=0.7, align='center')

# Line chart (Cumulative Percentage)
ax2 = ax1.twinx()
ax2.plot(frequency_table['Country'], frequency_table['Cummulative_frequency'], color='r', marker='o')

# Set labels and title
ax1.set_xlabel('Country')
ax1.set_ylabel('Absolute Frequency', color='b')
ax2.set_ylabel('Cumulative Frequency (%)', color='r')
plt.title('Pareto Diagram')

# Show the plot
plt.show()

# %%
import numpy as np
from scipy.stats import skew

# Extract the 'Price' column
price_data = df['Price'].dropna()  # Drop missing values, if any

# Mean
mean_price = np.mean(price_data)

# Median
median_price = np.median(price_data)

# Mode
mode_price = price_data.mode()[0]  # Using [0] as there might be multiple modes

# Skewness
skewness_price = skew(price_data)

# Variance
variance_price = np.var(price_data, ddof=1)  # Use ddof=1 for sample variance

# Standard Deviation
std_dev_price = np.std(price_data, ddof=1)  # Use ddof=1 for sample standard deviation

# Print the results
print(f"Mean Price: {mean_price:.2f}")
print(f"Median Price: {median_price:.2f}")
print(f"Mode Price: {mode_price:.2f}")
print(f"Skewness of Price: {skewness_price:.2f}")
print(f"Variance of Price: {variance_price:.2f}")
print(f"Standard Deviation of Price: {std_dev_price:.2f}")
# Out:
# Mean Price: 281171.90
# Median Price: 249075.66
# Mode Price: 460001.26
# Skewness of Price: 1.09
# Variance of Price: 7942217700.92
# Standard Deviation of Price: 89119.12

# %% [markdown]
# **Skewness of Price: 1.09**
#
# *Interpretation:*
#
# The skewness of 1.20 indicates a positive skew in the distribution of property prices. In practical terms, this means that the majority of properties tend to be relatively affordable, with a smaller proportion being more expensive. The distribution has a longer right tail, suggesting that while most properties fall within the lower to mid-price range, there is a smaller subset of properties with higher prices. This rightward skewness aligns with the idea that the market is characterized by a dominant presence of lower-priced properties, with only a limited number of higher-priced properti!git add .
# !git commit -m "Include output in notebook"
# es.

# %%
import pandas as pd

# Extract 'Price' and 'Area' columns
price_area_data = df[['Price', 'Area (ft.)']].dropna()  # Drop missing values, if any

# Calculate Covariance
covariance_price_area = price_area_data['Price'].cov(price_area_data['Area (ft.)'])

# Calculate Correlation Coefficient
correlation_price_area = price_area_data['Price'].corr(price_area_data['Area (ft.)'])

# Print the results
print(f"Covariance between Price and Area (ft.): {covariance_price_area:.2f}")
print(f"Correlation Coefficient between Price and Area (ft.): {correlation_price_area:.2f}")
# Out:
# Covariance between Price and Area (ft.): 24147721.73
# Correlation Coefficient between Price and Area (ft.): 0.95

# %% [markdown]
# **Covariance between Price and Area (ft.): 24,147,721.73**,
# **Correlation Coefficient between Price and Area (ft.): 0.95**
#
# *Interpretation:*
#
# The covariance between the "Price" and "Area" (in square feet) is positive, indicating that as the price of a property tends to increase, the area of the property also tends to increase. The magnitude of the covariance (24,147,721.73) signifies the strength of this linear relationship; however, it's challenging to interpret the magnitude directly.
#
# The correlation coefficient between "Price" and "Area" is 0.95, which is very close to 1. This strong positive correlation suggests a highly linear relationship between the two variables. In practical terms, as property prices increase, there is a strong tendency for the property area to increase as well. This aligns with the positive coefficient and is consistent with a scatter plot that shows a clear upward trend, supporting the idea that larger properties generally command higher p!git add .
# !git commit -m "Include output in notebook"
#
# prices.
